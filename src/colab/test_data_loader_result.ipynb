# %%
from numba import cuda
major, minor = cuda.get_current_device().compute_capability
print(f'GPU compute capability: {major}.{minor}')
# Out:
# GPU compute capability: 7.5

# %%
# !nvcc -arch=sm_{major}{minor} test_data_loader.cu data_loader.cu -o test_data_loader

# %%
# !./test_data_loader
# Out:
# ...
#   CIFAR-10 Data Loader (Google Colab Version)
# ...
# Data directory: /content/data
#
# === CUDA Device Check ===
#   Device:     Tesla T4
#   Capability: 7.5
#   Memory:     14.74 GB
#   Status:     CUDA Available
#
# Loading CIFAR-10 datasets from: /content/data
# Loading training data from /content/data...
#   ✓ Loaded batch 1/5
#   ✓ Loaded batch 2/5
#   ✓ Loaded batch 3/5
#   ✓ Loaded batch 4/5
#   ✓ Loaded batch 5/5
# ✓ Training data loaded: 50000 samples
#   Data range: [0.0000, 1.0000]
# ✓ Training dataset loaded: 50000 samples
# Loading test data from /content/data...
# ✓ Test data loaded: 10000 samples
#   Data range: [0.0000, 1.0000]
# ✓ Test dataset loaded: 10000 samples
# ✓ Total datasets loaded: 60000 samples
#
# ...
# TEST 1: Training Dataset (50,000 images)
# ...
#
# Running verification tests:
#   [PASS] Training sample count: 50000 (expected 50000)
#   [PASS] Training dimensions: 32x32x3 (expected 32x32x3)
#   [PASS] Training normalized to [0,1]: range [0.0000, 1.0000]
# ...
