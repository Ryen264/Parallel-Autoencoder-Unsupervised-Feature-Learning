# %%
from numba import cuda
major, minor = cuda.get_current_device().compute_capability
print(f'GPU compute capability: {major}.{minor}')
# Out:
# GPU compute capability: 7.5

# %%
from google.colab import drive
drive.mount('/content/drive')
# /content/drive/MyDrive/@fithcmú/LapTrinhSongSong/data/cifar-10-batches-bin
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/cjlin1/libsvm.git
# Install/clone cuLM library for <cuml/svm/svm.hpp>
# !git clone https://github.com/rapidsai/cuml.git
# %cd cuml
# Out:
# fatal: destination path 'libsvm' already exists and is not an empty directory.

# %%
# !nvcc -arch=sm_{major}{minor} \
  /content/main.cu \
  /content/data_loader.cu \
  /content/model.cu \
  /content/visualization.cu \
  /content/cpu_layers.cu \
  /content/cpu_autoencoder.cu \
  /content/libsvm/svm.cpp \
  -o main

# %%
#!./main [RUN_MODE] [USE_DUMMY_DATA]
# !./main all False
# Out:
# Phase 1: Training Autoencoder
# Loading training data from /content/drive/MyDrive/@fithcmú/LapTrinhSongSong/data/cifar-10-batches-bin...
#   ✓ Loaded batch 1/5
#   ✓ Loaded batch 2/5
#   ✓ Loaded batch 3/5
#   ✓ Loaded batch 4/5
#   ✓ Loaded batch 5/5
# ✓ Training data loaded: 50000 samples
#   Data range: [0.0000, 1.0000]
# Training Autoencoder for 20 epochs with batch size 32 and learning rate 0.0010
# =======================TRAINING START=======================
# Epoch 1:
