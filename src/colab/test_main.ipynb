# %%
from numba import cuda
major, minor = cuda.get_current_device().compute_capability
print(f'GPU compute capability: {major}.{minor}')
# Out:
# GPU compute capability: 7.5

# %%
# !git clone https://github.com/cjlin1/libsvm.git
# Out:
# Cloning into 'libsvm'...
# remote: Enumerating objects: 4201, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 4201 (delta 140), reused 118 (delta 118), pack-reused 3971 (from 3)
# Receiving objects: 100% (4201/4201), 9.92 MiB | 15.99 MiB/s, done.
# Resolving deltas: 100% (2317/2317), done.

# %%
# !nvcc -arch=sm_{major}{minor} \
  /content/main.cu \
  /content/data_loader.cu \
  /content/model.cu \
  /content/visualization.cu \
  /content/cpu_autoencoder.cu \
  /content/libsvm/svm.cpp \
  -o main
# Out:
# /usr/bin/ld: /tmp/tmpxft_00002d31_00000000-39_cpu_autoencoder.o: in function `Cpu_Autoencoder::Cpu_Autoencoder()':
# tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x32): undefined reference to `IAutoencoder::IAutoencoder()'
# /usr/bin/ld: /tmp/tmpxft_00002d31_00000000-39_cpu_autoencoder.o: in function `Cpu_Autoencoder::Cpu_Autoencoder(char const*)':
# tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x6b): undefined reference to `IAutoencoder::IAutoencoder(char const*)'
# /usr/bin/ld: /tmp/tmpxft_00002d31_00000000-39_cpu_autoencoder.o: in function `Cpu_Autoencoder::_encode_save_output(Dataset const&)':
# tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x11d): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x17f): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1c7): undefined reference to `cpu_relu(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x20b): undefined reference to `cpu_max_pooling(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x282): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2fc): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x35d): undefined reference to `cpu_relu(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x3ba): undefined reference to `cpu_max_pooling(float*, float*, int, int, int, int)'
# /usr/bin/ld: /tmp/tmpxft_00002d31_00000000-39_cpu_autoencoder.o: in function `Cpu_Autoencoder::_decode_save_output(Dataset const&)':
# tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x51d): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x57f): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x5c9): undefined reference to `cpu_relu(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x611): undefined reference to `cpu_upsampling(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x67e): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x6ee): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x741): undefined reference to `cpu_relu(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x790): undefined reference to `cpu_upsampling(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x802): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x877): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: /tmp/tmpxft_00002d31_00000000-39_cpu_autoencoder.o: in function `Cpu_Autoencoder::_fit_batch(Dataset const&, float)':
# tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x11bb): undefined reference to `cpu_mse_loss(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x121a): undefined reference to `cpu_mse_grad(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x124c): undefined reference to `cpu_bias_grad(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1285): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x12d1): undefined reference to `cpu_conv2D_grad(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1324): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1374): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x13b8): undefined reference to `cpu_upsampling_backward(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1421): undefined reference to `cpu_relu_backward(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1469): undefined reference to `cpu_bias_grad(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x14a2): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1509): undefined reference to `cpu_conv2D_grad(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1577): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x15c7): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x160f): undefined reference to `cpu_upsampling_backward(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x167a): undefined reference to `cpu_relu_backward(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x16c6): undefined reference to `cpu_bias_grad(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x16fd): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1766): undefined reference to `cpu_conv2D_grad(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x17d6): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1824): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x188b): undefined reference to `cpu_max_pooling_backward(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x18f6): undefined reference to `cpu_relu_backward(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x193e): undefined reference to `cpu_bias_grad(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1975): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x19da): undefined reference to `cpu_conv2D_grad(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1a46): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1a94): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1ae3): undefined reference to `cpu_max_pooling_backward(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1b36): undefined reference to `cpu_relu_backward(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1b68): undefined reference to `cpu_bias_grad(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1b9f): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1beb): undefined reference to `cpu_conv2D_grad(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1c42): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1c90): undefined reference to `cpu_update_weight(float*, float*, int, float)'
# /usr/bin/ld: /tmp/tmpxft_00002d31_00000000-39_cpu_autoencoder.o: in function `Cpu_Autoencoder::fit(Dataset const&, int, int, float, bool, int, char const*)':
# tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x1ff1): undefined reference to `IAutoencoder::_save_paramters(char const*) const'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x20ce): undefined reference to `IAutoencoder::_save_paramters(char const*) const'
# /usr/bin/ld: /tmp/tmpxft_00002d31_00000000-39_cpu_autoencoder.o: in function `Cpu_Autoencoder::encode(Dataset const&) const':
# tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2344): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x239e): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x23de): undefined reference to `cpu_relu(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x241a): undefined reference to `cpu_max_pooling(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2489): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x24fb): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2554): undefined reference to `cpu_relu(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x25a9): undefined reference to `cpu_max_pooling(float*, float*, int, int, int, int)'
# /usr/bin/ld: /tmp/tmpxft_00002d31_00000000-39_cpu_autoencoder.o: in function `Cpu_Autoencoder::decode(Dataset const&) const':
# tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x288e): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x28e8): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2928): undefined reference to `cpu_relu(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2964): undefined reference to `cpu_upsampling(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x29c5): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2a29): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2a70): undefined reference to `cpu_relu(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2ab3): undefined reference to `cpu_upsampling(float*, float*, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2b19): undefined reference to `cpu_conv2D(float*, float*, float*, int, int, int, int, int)'
# /usr/bin/ld: tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2b82): undefined reference to `cpu_add_bias(float*, float*, float*, int, int, int, int)'
# /usr/bin/ld: /tmp/tmpxft_00002d31_00000000-39_cpu_autoencoder.o: in function `Cpu_Autoencoder::eval(Dataset const&)':
# tmpxft_00002d31_00000000-22_cpu_autoencoder.cudafe1.cpp:(.text+0x2dc6): undefined reference to `cpu_mse_loss(float*, float*, int, int, int, int)'
# collect2: error: ld returned 1 exit status

# %%
#./main [RUN_MODE] [N] [WIDTH] [HEIGHT] [DEPTH] [USE_DUMMY_DATA]
./main
# Out:
#   File "/tmp/ipython-input-1744814664.py", line 2
#     ./main
#     ^
# SyntaxError: invalid syntax
