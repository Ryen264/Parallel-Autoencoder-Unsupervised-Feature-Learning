# %%
from numba import cuda
major, minor = cuda.get_current_device().compute_capability
print(f'GPU compute capability: {major}.{minor}')
# Out:
# GPU compute capability: 7.5

# %%
# !git clone https://github.com/cjlin1/libsvm.git
# Out:
# fatal: destination path 'libsvm' already exists and is not an empty directory.

# %%
# !nvcc -arch=sm_{major}{minor} \
  /content/main.cu \
  /content/data_loader.cu \
  /content/model.cu \
  /content/visualization.cu \
  /content/cpu_layers.cu \
  /content/cpu_autoencoder.cu \
  /content/libsvm/svm.cpp \
  -o main
# Out:
# /usr/bin/ld: /tmp/tmpxft_00000725_00000000-46_cpu_autoencoder.o: in function `Cpu_Autoencoder::fit(Dataset const&, int, int, float, bool, int, char const*)':
# tmpxft_00000725_00000000-26_cpu_autoencoder.cudafe1.cpp:(.text+0x2e8a): undefined reference to `Cpu_Autoencoder::save_paramters(char const*) const'
# /usr/bin/ld: tmpxft_00000725_00000000-26_cpu_autoencoder.cudafe1.cpp:(.text+0x2f6a): undefined reference to `Cpu_Autoencoder::save_paramters(char const*) const'
# collect2: error: ld returned 1 exit status

# %%
#./main [RUN_MODE] [USE_DUMMY_DATA]
./main
# Out:
#   File "/tmp/ipython-input-1744814664.py", line 2
#     ./main
#     ^
# SyntaxError: invalid syntax
